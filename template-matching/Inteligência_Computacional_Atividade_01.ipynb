# %% [markdown]
# # TEMPLATE MATCHING
#
# [Atividade 01](https://docs.google.com/document/d/1MS7VMELifmCachXZah9KDwy-fkmDWxFZJJIGkS0tYUY/edit)

# %%
from statistics import mean
import sys
sys.path.append('/Users/gzanoni/dev/inteligencia-computacional/')
from utils.utils import Utils
from compareClass import CompareClass

u = Utils()
cmp = CompareClass()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/gzanoni/dev/inteligencia-computacional/template-matching/Inteligência_Computacional_Atividade_01.ipynb Célula 2 line 2
#       <a href='vscode-notebook-cell:/Users/gzanoni/dev/inteligencia-computacional/template-matching/Intelig%C3%AAncia_Computacional_Atividade_01.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from statistics import mean
# ----> <a href='vscode-notebook-cell:/Users/gzanoni/dev/inteligencia-computacional/template-matching/Intelig%C3%AAncia_Computacional_Atividade_01.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> from utils import Utils
#       <a href='vscode-notebook-cell:/Users/gzanoni/dev/inteligencia-computacional/template-matching/Intelig%C3%AAncia_Computacional_Atividade_01.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> from compareClass import CompareClass
#       <a href='vscode-notebook-cell:/Users/gzanoni/dev/inteligencia-computacional/template-matching/Intelig%C3%AAncia_Computacional_Atividade_01.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> u = Utils()
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# ### Etapa A - Template Matching
#
# 1.   Baixe a base “four shapes”  [aqui](https://www.dropbox.com/scl/fi/csk3cor9zln3fc957mf77/fourShapes.tar.gz?rlkey=3v44mpdt0qtsne56fzwkwwr5r&dl=0).
# 2.   Observe as diferenças e semelhanças entre as amostras das quatro classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes;
#         *   Escolha uma (1) imagem como “template” e três imagens da mesma classe como entradas ;
#         *   Calcule Pearson e Erro Quadrárico Médio entre elas;
#         *   Utilizando o mesmo “template”, selecione três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas;
# 4.   Descreva se os os menores coeficientes são referentes as amostras da mesma classe ou de classes diferentes.
# 5.   Descreva para cada uma das quatro classes, quais são as amostras mais similares.

# %%
def test_template_matching(folder, resize=(200, 200), border_color=(0, 0, 0)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando o template com as instâncias da classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                psn.append(cmp.pearson_correlation(conjunto_formas[classe][0], f, resize, border_color))
                mse.append(cmp.mse(conjunto_formas[classe][0], f, resize, border_color))
                print(f"Imagem: {f} - Pearson: {psn[-1]} - MSE: { mse[-1]}")
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            #print("Média para:")
            print(f"Média dos resultados de Pearson: {mean(psn)}\nMédia dos resultados de MSE: {mean(mse)}")
        print("========================================================")

# %%
test_template_matching("fourShapes/", resize=(200, 200), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: star
# Template: fourShapes/star/1179.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1642.png - Pearson: 0.7844353608371555 - MSE: 2.467325
# Imagem: fourShapes/star/2301.png - Pearson: 0.5417662074219446 - MSE: 2.32355
# Imagem: fourShapes/star/2088.png - Pearson: 0.5337421589388096 - MSE: 2.2489
# Média dos resultados de Pearson: 0.6199812423993032
# Média dos resultados de MSE: 2.346591666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.617237386340022 - MSE: 2.5691
# Imagem: fourShapes/circle/985.png - Pearson: 0.616848680983515 - MSE: 2.283
# Imagem: fourShapes/circle/805.png - Pearson: 0.6182081521057033 - MSE: 2.174325
# Média dos resultados de Pearson: 0.6174314064764135
# Média dos resultados de MSE: 2.3421416666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/2097.png - Pearson: 0.6295831021633564 - MSE: 2.195
# Imagem: fourShapes/square/847.png - Pearson: 0.686628077951345 - MSE: 2.200675
# Imagem: fourShapes/square/461.png - Pearson: 0.6475281323393139 - MSE: 2.1212
# Média dos resultados de Pearson: 0.6545797708180051
# Média dos resultados de MSE: 2.1722916666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.6785313051576528 - MSE: 2.252725
# Imagem: fourShapes/triangle/616.png - Pearson: 0.5948296568719316 - MSE: 2.004
# Imagem: fourShapes/triangle/956.png - Pearson: 0.627484574902011 - MSE: 2.074325
# Média dos resultados de Pearson: 0.6336151789771984
# Média dos resultados de MSE: 2.11035
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/253.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1642.png - Pearson: 0.6070702412377919 - MSE: 2.735725
# Imagem: fourShapes/star/2301.png - Pearson: 0.6033999807001063 - MSE: 2.6203
# Imagem: fourShapes/star/2088.png - Pearson: 0.5570684206033634 - MSE: 2.46475
# Média dos resultados de Pearson: 0.5891795475137538
# Média dos resultados de MSE: 2.606925
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.9803025832299228 - MSE: 2.134
# Imagem: fourShapes/circle/985.png - Pearson: 0.9700249155355574 - MSE: 1.95825
# Imagem: fourShapes/circle/805.png - Pearson: 0.978003875692548 - MSE: 1.957275
# Média dos resultados de Pearson: 0.976110458152676
# Média dos resultados de MSE: 2.0165083333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/2097.png - Pearson: 0.868350191041361 - MSE: 2.1267
# Imagem: fourShapes/square/847.png - Pearson: 0.7848370816624295 - MSE: 2.376725
# Imagem: fourShapes/square/461.png - Pearson: 0.8569230500690485 - MSE: 2.32665
# Média dos resultados de Pearson: 0.8367034409242796
# Média dos resultados de MSE: 2.276691666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.6020619280747981 - MSE: 2.474225
# Imagem: fourShapes/triangle/616.png - Pearson: 0.5995140970466537 - MSE: 2.2212
# Imagem: fourShapes/triangle/956.png - Pearson: 0.6293179561098026 - MSE: 2.326975
# Média dos resultados de Pearson: 0.6102979937437515
# Média dos resultados de MSE: 2.3408
# ========================================================
# ========================================================
# Classe: square
# Template: fourShapes/square/2377.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1642.png - Pearson: 0.6787832512236699 - MSE: 2.1039
# Imagem: fourShapes/star/2301.png - Pearson: 0.6614056539633788 - MSE: 1.884375
# Imagem: fourShapes/star/2088.png - Pearson: 0.6447745642953351 - MSE: 1.753125
# Média dos resultados de Pearson: 0.6616544898274612
# Média dos resultados de MSE: 1.9138
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.8058260212170866 - MSE: 2.012575
# Imagem: fourShapes/circle/985.png - Pearson: 0.811650138660227 - MSE: 1.700725
# Imagem: fourShapes/circle/805.png - Pearson: 0.8129397031351188 - MSE: 1.5684
# Média dos resultados de Pearson: 0.8101386210041441
# Média dos resultados de MSE: 1.7605666666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/2097.png - Pearson: 0.8542438677793461 - MSE: 1.601125
# Imagem: fourShapes/square/847.png - Pearson: 0.8882376309628728 - MSE: 1.61855
# Imagem: fourShapes/square/461.png - Pearson: 0.8704706265106863 - MSE: 1.693825
# Média dos resultados de Pearson: 0.8709840417509684
# Média dos resultados de MSE: 1.6378333333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.6875130205677156 - MSE: 1.88075
# Imagem: fourShapes/triangle/616.png - Pearson: 0.6759986715903467 - MSE: 1.556325
# Imagem: fourShapes/triangle/956.png - Pearson: 0.6515767592976943 - MSE: 1.6752
# Média dos resultados de Pearson: 0.6716961504852522
# Média dos resultados de MSE: 1.7040916666666666
# ========================================================
# ========================================================
# Classe: triangle
# Template: fourShapes/triangle/833.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1642.png - Pearson: 0.6139211859579592 - MSE: 2.281225
# Imagem: fourShapes/star/2301.png - Pearson: 0.605761114066382 - MSE: 1.97935
# Imagem: fourShapes/star/2088.png - Pearson: 0.607633906709207 - MSE: 1.95405
# Média dos resultados de Pearson: 0.609105402244516
# Média dos resultados de MSE: 2.0715416666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.6517391985170893 - MSE: 2.18375
# Imagem: fourShapes/circle/985.png - Pearson: 0.6500157049350622 - MSE: 1.8414
# Imagem: fourShapes/circle/805.png - Pearson: 0.6587409900211763 - MSE: 1.767925
# Média dos resultados de Pearson: 0.653498631157776
# Média dos resultados de MSE: 1.931025
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/2097.png - Pearson: 0.6984475757882577 - MSE: 1.8079
# Imagem: fourShapes/square/847.png - Pearson: 0.7372755911029748 - MSE: 1.784725
# Imagem: fourShapes/square/461.png - Pearson: 0.7284612642158776 - MSE: 1.6431
# Média dos resultados de Pearson: 0.7213948103690367
# Média dos resultados de MSE: 1.7452416666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.6949456628189141 - MSE: 1.844975
# Imagem: fourShapes/triangle/616.png - Pearson: 0.6013314105582062 - MSE: 1.78285
# Imagem: fourShapes/triangle/956.png - Pearson: 0.7666773306746596 - MSE: 1.761625
# Média dos resultados de Pearson: 0.68765146801726
# Média dos resultados de MSE: 1.7964833333333334
# ========================================================

# %% [markdown]
# ### Etapa B: Template Matching
#
# 1.   Refaça os experimentos da Etapa A usando a base de folhas ([download](https://www.dropbox.com/s/fmbq1bpay5joaax/Folhas.zip?dl=0)) ;
# 2.   Selecione 3 imagens aleatórias de cada uma das 3 classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       *  Escolha uma imagem como “template” e três imagens da mesma classe como entradas;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas ;
# 4.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %%
test_template_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/499.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/216.jpg - Pearson: 0.8137896829683431 - MSE: 2.386688
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.7347093953105717 - MSE: 2.466824
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.8902820831901572 - MSE: 1.894284
# Média dos resultados de Pearson: 0.812927053823024
# Média dos resultados de MSE: 2.2492653333333332
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.5933196025038687 - MSE: 2.267296
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.6159950339987466 - MSE: 2.22428
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.6094771301480624 - MSE: 2.321516
# Média dos resultados de Pearson: 0.6062639222168925
# Média dos resultados de MSE: 2.2710306666666664
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.7138364398210302 - MSE: 1.98608
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.7475883784807363 - MSE: 2.04692
# Imagem: folhas/Acer_Capillipes/569.jpg - Pearson: 0.7548112880583807 - MSE: 1.927188
# Média dos resultados de Pearson: 0.7387453687867157
# Média dos resultados de MSE: 1.9867293333333333
# ========================================================
# ========================================================
# Classe: Acer_Opalus
# Template: folhas/Acer_Opalus/1002.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/216.jpg - Pearson: 0.5950496126265411 - MSE: 1.989196
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.5510471909042371 - MSE: 2.044948
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.6385308006149889 - MSE: 1.510528
# Média dos resultados de Pearson: 0.594875868048589
# Média dos resultados de MSE: 1.848224
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.696060583812728 - MSE: 1.59638
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.7897638427680757 - MSE: 1.551172
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.7103964841522483 - MSE: 1.685944
# Média dos resultados de Pearson: 0.7320736369110173
# Média dos resultados de MSE: 1.6111653333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.6238750213126082 - MSE: 1.472964
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.5934092807278301 - MSE: 1.55874
# Imagem: folhas/Acer_Capillipes/569.jpg - Pearson: 0.6273006512638779 - MSE: 1.431008
# Média dos resultados de Pearson: 0.6148616511014388
# Média dos resultados de MSE: 1.4875706666666666
# ========================================================
# ========================================================
# Classe: Acer_Capillipes
# Template: folhas/Acer_Capillipes/227.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/216.jpg - Pearson: 0.6762297741510797 - MSE: 1.873984
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.5694772084473074 - MSE: 1.980528
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.7103752136879873 - MSE: 1.4393
# Média dos resultados de Pearson: 0.6520273987621248
# Média dos resultados de MSE: 1.764604
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.6437333559683306 - MSE: 1.607432
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.6324168567576618 - MSE: 1.593608
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.6026260393778513 - MSE: 1.709668
# Média dos resultados de Pearson: 0.6262587507012812
# Média dos resultados de MSE: 1.6369026666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.9184362379258156 - MSE: 1.266176
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.907200341076269 - MSE: 1.347304
# Imagem: folhas/Acer_Capillipes/569.jpg - Pearson: 0.9058635708263113 - MSE: 1.235428
# Média dos resultados de Pearson: 0.9105000499427987
# Média dos resultados de MSE: 1.2829693333333334
# ========================================================

# %% [markdown]
# ### Etapa C: Feature Matching
#
# 1.  Refaça os experimentos da Etapa A e B usando características extraídas das imagens ;
# 2.  Utilize uma característica simples como contagem de pixels pretos e brancos em zonas da imagem (3x3) ;
# 3.  Selecione as mesmas amostras como template e para calcular as diferenças.
# 4.  Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       * Escolha uma imagem como “template” e três imagens da mesma classe como entradas ;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas;
# 5.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %% [markdown]
# ##### Four-Shapes (Etapa A)

# %%
def test_feature_matching(folder, num_parts=3, resize=(60, 60), border_color=(255,255,255)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])
        template = cmp.count_pixels(str(conjunto_formas[classe][0]), num_parts, resize, border_color)

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando o template com as instâncias da classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                image = cmp.count_pixels(str(f), num_parts, resize, border_color)
                res = cmp.compare_arrays(template, image)
                psn.append(res[0])
                mse.append(res[1])
                print(f"Imagem: {f} - Pearson: {psn[-1]} - MSE: { mse[-1]}")
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            #print("Média para:")
            print(f"Média dos resultados de Pearson: {mean(psn)}\nMédia dos resultados de MSE: {mean(mse)}")

        print("========================================================")

# %%
test_feature_matching("fourShapes/", resize=(200, 200), border_color=(255, 255, 255))
# Out:
# ========================================================
# Classe: star
# Template: fourShapes/star/2088.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1500.png - Pearson: 0.997431304263255 - MSE: 210268.0
# Imagem: fourShapes/star/1642.png - Pearson: 0.9937289944462274 - MSE: 292419.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.9955521681473378 - MSE: 226938.0
# Média dos resultados de Pearson: 0.9955708222856068
# Média dos resultados de MSE: 243208.33333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2661.png - Pearson: 0.9583840411880975 - MSE: 4570330.0
# Imagem: fourShapes/circle/1387.png - Pearson: 0.9074289136302175 - MSE: 8857060.0
# Imagem: fourShapes/circle/253.png - Pearson: 0.9124584441027791 - MSE: 8398414.0
# Média dos resultados de Pearson: 0.9260904663070314
# Média dos resultados de MSE: 7275268.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1166.png - Pearson: 0.9587982266016479 - MSE: 4585217.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.964537416623098 - MSE: 3931999.0
# Imagem: fourShapes/square/847.png - Pearson: 0.9825167704914425 - MSE: 2875676.0
# Média dos resultados de Pearson: 0.9686174712387294
# Média dos resultados de MSE: 3797630.6666666665
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.982779563040713 - MSE: 457246.0
# Imagem: fourShapes/triangle/1131.png - Pearson: 0.9760070159357315 - MSE: 1230428.0
# Imagem: fourShapes/triangle/374.png - Pearson: 0.9916802418033179 - MSE: 768652.0
# Média dos resultados de Pearson: 0.9834889402599208
# Média dos resultados de MSE: 818775.3333333334
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/1541.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1500.png - Pearson: 0.9897675264098851 - MSE: 351834.0
# Imagem: fourShapes/star/1642.png - Pearson: 0.9667900740675415 - MSE: 821135.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.9769044055144975 - MSE: 629132.0
# Média dos resultados de Pearson: 0.9778206686639747
# Média dos resultados de MSE: 600700.3333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2661.png - Pearson: 0.937870887733873 - MSE: 2831802.0
# Imagem: fourShapes/circle/1387.png - Pearson: 0.8914650480468598 - MSE: 6120268.0
# Imagem: fourShapes/circle/253.png - Pearson: 0.8961249630615408 - MSE: 5752286.0
# Média dos resultados de Pearson: 0.9084869662807579
# Média dos resultados de MSE: 4901452.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1166.png - Pearson: 0.9403722981662629 - MSE: 2782599.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.9470037802207019 - MSE: 2327221.0
# Imagem: fourShapes/square/847.png - Pearson: 0.961590851547655 - MSE: 1607594.0
# Média dos resultados de Pearson: 0.94965564331154
# Média dos resultados de MSE: 2239138.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/11.png - Pearson: 0.95338529644611 - MSE: 1115450.0
# Imagem: fourShapes/triangle/1131.png - Pearson: 0.9951175878720652 - MSE: 124412.0
# Imagem: fourShapes/triangle/374.png - Pearson: 0.9940732944953824 - MSE: 129452.0
# Média dos resultados de Pearson: 0.9808587262711859
# Média dos resultados de MSE: 456438.0
# ========================================================

# %% [markdown]
# ##### Folhas (Etapa B)

# %%
test_feature_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/288.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.9100118959422271 - MSE: 125645710.0
# Imagem: folhas/Acer_Mono/216.jpg - Pearson: 0.9602564509026836 - MSE: 52217895.0
# Imagem: folhas/Acer_Mono/807.jpg - Pearson: 0.941269098911824 - MSE: 73811430.0
# Média dos resultados de Pearson: 0.9371791485855783
# Média dos resultados de MSE: 83891678.33333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.829951220943203 - MSE: 610326852.0
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.783333725673012 - MSE: 722539574.0
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.8701130191522657 - MSE: 468866662.0
# Média dos resultados de Pearson: 0.8277993219228269
# Média dos resultados de MSE: 600577696.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe