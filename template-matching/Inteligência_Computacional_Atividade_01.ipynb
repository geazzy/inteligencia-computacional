# %% [markdown]
# # TEMPLATE MATCHING
#
# [Atividade 01](https://docs.google.com/document/d/1MS7VMELifmCachXZah9KDwy-fkmDWxFZJJIGkS0tYUY/edit)

# %%
from statistics import mean
from utils import Utils
from compareClass import CompareClass

u = Utils()
cmp = CompareClass()

# %% [markdown]
# ### Etapa A - Template Matching
#
# 1.   Baixe a base “four shapes”  [aqui](https://www.dropbox.com/scl/fi/csk3cor9zln3fc957mf77/fourShapes.tar.gz?rlkey=3v44mpdt0qtsne56fzwkwwr5r&dl=0).
# 2.   Observe as diferenças e semelhanças entre as amostras das quatro classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes;
#         *   Escolha uma (1) imagem como “template” e três imagens da mesma classe como entradas ;
#         *   Calcule Pearson e Erro Quadrárico Médio entre elas;
#         *   Utilizando o mesmo “template”, selecione três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas;
# 4.   Descreva se os os menores coeficientes são referentes as amostras da mesma classe ou de classes diferentes.
# 5.   Descreva para cada uma das quatro classes, quais são as amostras mais similares.

# %%
def test_template_matching(folder, resize=(200, 200), border_color=(0, 0, 0)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando com a classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                psn.append(cmp.pearson_correlation(conjunto_formas[classe][0], f, resize, border_color))
                mse.append(cmp.mse(conjunto_formas[classe][0], f, resize, border_color))
                # print("Imagem:", f)
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            print("Resultado:")
            print(f"Pearson: {mean(psn)}\nMSE: {mean(mse)}")
        print("========================================================")

# %%
test_template_matching("fourShapes/", resize=(200, 200), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: star
# Template: fourShapes/star/1014.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6419830492619805
# MSE: 2.4309833333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.637604264362231
# MSE: 2.3291749999999998
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6378439927137987
# MSE: 2.1128
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6350554557248641
# MSE: 2.2089833333333333
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/1721.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6088638072070588
# MSE: 2.20105
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.9295945744010741
# MSE: 1.759325
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.8528836450216077
# MSE: 1.6539166666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6248861058257256
# MSE: 1.94545
# ========================================================
# ========================================================
# Classe: square
# Template: fourShapes/square/847.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.672288498398162
# MSE: 2.1704333333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.8169104805731847
# MSE: 2.0152583333333336
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.8444563366154837
# MSE: 1.7097833333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6900777590011843
# MSE: 1.92345
# ========================================================
# ========================================================
# Classe: triangle
# Template: fourShapes/triangle/374.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5931076810357501
# MSE: 2.1283416666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6573017155687837
# MSE: 2.05365
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6636325385984154
# MSE: 1.839425
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.6547711332259439
# MSE: 1.9051916666666666
# ========================================================

# %% [markdown]
# ### Etapa B: Template Matching
#
# 1.   Refaça os experimentos da Etapa A usando a base de folhas ([download](https://www.dropbox.com/s/fmbq1bpay5joaax/Folhas.zip?dl=0)) ;
# 2.   Selecione 3 imagens aleatórias de cada uma das 3 classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       *  Escolha uma imagem como “template” e três imagens da mesma classe como entradas;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas ;
# 4.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %%
test_template_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/288.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.752523523929433
# MSE: 2.2122573333333335
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5173078591384741
# MSE: 2.2342400000000002
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5860829566540998
# MSE: 1.910948
# ========================================================
# ========================================================
# Classe: Acer_Opalus
# Template: folhas/Acer_Opalus/317.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5790993355034392
# MSE: 2.1106506666666665
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.8119366779352899
# MSE: 1.741524
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5812957505844402
# MSE: 1.6572506666666666
# ========================================================
# ========================================================
# Classe: Acer_Capillipes
# Template: folhas/Acer_Capillipes/201.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.7118747429354777
# MSE: 1.817716
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.5709422535351032
# MSE: 1.7375013333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# imagens
# imagens
# imagens
# Resultado:
# Pearson: 0.8867237362432508
# MSE: 1.307708
# ========================================================

# %% [markdown]
# ### Etapa C: Feature Matching
#
# 1.  Refaça os experimentos da Etapa A e B usando características extraídas das imagens ;
# 2.  Utilize uma característica simples como contagem de pixels pretos e brancos em zonas da imagem (3x3) ;
# 3.  Selecione as mesmas amostras como template e para calcular as diferenças.
# 4.  Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       * Escolha uma imagem como “template” e três imagens da mesma classe como entradas ;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas;
# 5.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %% [markdown]
# ##### Four-Shapes (Etapa A)

# %%
def test_feature_matching(folder, num_parts=3, resize=(60, 60), border_color=(255,255,255)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])
        template = cmp.count_pixels(str(conjunto_formas[classe][0]), num_parts, resize, border_color)

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando com a classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                image = cmp.count_pixels(str(f), num_parts, resize, border_color)
                res = cmp.compare_arrays(template, image)
                psn.append(res[0])
                mse.append(res[1])
                # print("Imagem:", f)
                # # print("Vetor", image)
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            print("MÉDIA:")
            print(f"Pearson: {mean(psn)}\nMSE: {mean(mse)}")
        print("========================================================")

# %%
test_feature_matching("fourShapes/", resize=(200, 200), border_color=(255, 255, 255))
# Out:
# ========================================================
# Classe: star
# Template: fourShapes/star/2301.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# MÉDIA:
# Pearson: 0.9939471379985858
# MSE: 191032.33333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# MÉDIA:
# Pearson: 0.925699431735183
# MSE: 6462307.333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# MÉDIA:
# Pearson: 0.969238519009945
# MSE: 4949659.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# MÉDIA:
# Pearson: 0.9665238847453117
# MSE: 929597.6666666666
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/2661.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# MÉDIA:
# Pearson: 0.9609161574086382
# MSE: 3903796.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# MÉDIA:
# Pearson: 0.9911660184192208
# MSE: 807923.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# MÉDIA:
# Pearson: 0.9965582178103419
# MSE: 725126.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# MÉDIA:
# Pearson: 0.939987278209986
# MSE: 2581507.3333333335
# ========================================================
# ========================================================
# Classe: square
# Template: fourShapes/square/847.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# MÉDIA:
# Pearson: 0.9845909516760158
# MSE: 2300159.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# MÉDIA:
# Pearson: 0.9611055895695932
# MSE: 2419006.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# MÉDIA:
# Pearson: 0.9896839798269421
# MSE: 1594772.3333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# MÉDIA:
# Pearson: 0.9578626727947182
# MSE: 1578681.6666666667
# ========================================================
# ========================================================
# Classe: triangle
# Template: fourShapes/triangle/1131.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: star
#
# MÉDIA:
# Pearson: 0.9714104979634259
# MSE: 1100597.6666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: circle
#
# MÉDIA:
# Pearson: 0.8894203229761427
# MSE: 5488879.333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: square
#
# MÉDIA:
# Pearson: 0.9267040747734944
# MSE: 4117220.3333333335
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: triangle
#
# MÉDIA:
# Pearson: 0.9362636181436084
# MSE: 1371739.0
# ========================================================

# %% [markdown]
# ##### Folhas (Etapa B)

# %%
test_feature_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/288.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# MÉDIA:
# Pearson: 0.9356899209304657
# MSE: 85155428.66666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# MÉDIA:
# Pearson: 0.8158500331635148
# MSE: 612317432.6666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# MÉDIA:
# Pearson: 0.7885028596059317
# MSE: 327500351.0
# ========================================================
# ========================================================
# Classe: Acer_Opalus
# Template: folhas/Acer_Opalus/906.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# MÉDIA:
# Pearson: 0.8995618792659225
# MSE: 501384415.3333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# MÉDIA:
# Pearson: 0.9719827476427103
# MSE: 53611830.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# MÉDIA:
# Pearson: 0.7703635662593113
# MSE: 552665515.0
# ========================================================
# ========================================================
# Classe: Acer_Capillipes
# Template: folhas/Acer_Capillipes/227.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Mono
#
# MÉDIA:
# Pearson: 0.9361165353022818
# MSE: 124719166.66666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Opalus
#
# MÉDIA:
# Pearson: 0.8270131838748916
# MSE: 367067782.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando com a classe: Acer_Capillipes
#
# MÉDIA:
# Pearson: 0.9955732767286359
# MSE: 12640581.666666666
# ========================================================
