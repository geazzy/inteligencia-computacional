# %% [markdown]
# # TEMPLATE MATCHING
#
# [Atividade 01](https://docs.google.com/document/d/1MS7VMELifmCachXZah9KDwy-fkmDWxFZJJIGkS0tYUY/edit)

# %%
from statistics import mean
import sys
sys.path.append('/Users/gzanoni/dev/inteligencia-computacional/') # path to the project
from utils.utils import Utils
from compareClass import CompareClass

u = Utils()
cmp = CompareClass()

# %% [markdown]
# ### Etapa A - Template Matching
#
# 1.   Baixe a base “four shapes”  [aqui](https://www.dropbox.com/scl/fi/csk3cor9zln3fc957mf77/fourShapes.tar.gz?rlkey=3v44mpdt0qtsne56fzwkwwr5r&dl=0).
# 2.   Observe as diferenças e semelhanças entre as amostras das quatro classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes;
#         *   Escolha uma (1) imagem como “template” e três imagens da mesma classe como entradas ;
#         *   Calcule Pearson e Erro Quadrárico Médio entre elas;
#         *   Utilizando o mesmo “template”, selecione três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas;
# 4.   Descreva se os os menores coeficientes são referentes as amostras da mesma classe ou de classes diferentes.
# 5.   Descreva para cada uma das quatro classes, quais são as amostras mais similares.

# %%
def test_template_matching(folder, resize=(200, 200), border_color=(0, 0, 0)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando o template com as instâncias da classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                psn.append(cmp.pearson_correlation(conjunto_formas[classe][0], f, resize, border_color))
                mse.append(cmp.mse(conjunto_formas[classe][0], f, resize, border_color))
                print(f"Imagem: {f} - Pearson: {psn[-1]} - MSE: { mse[-1]}")
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            #print("Média para:")
            print(f"Média dos resultados de Pearson: {mean(psn)}\nMédia dos resultados de MSE: {mean(mse)}")
        print("========================================================")

# %%
test_template_matching("fourShapes/", resize=(200, 200), border_color=(0, 0, 0))
# Out:
# numero de arquivos:  40
# ========================================================
# Classe: square
# Template: fourShapes/square/847.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/57.png - Pearson: 0.8709763003254536 - MSE: 1.711975
# Imagem: fourShapes/square/1338.png - Pearson: 0.791233043105309 - MSE: 1.777425
# Imagem: fourShapes/square/1824.png - Pearson: 0.789975466621667 - MSE: 1.989725
# Média dos resultados de Pearson: 0.8173949366841432
# Média dos resultados de MSE: 1.826375
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.7372755911013906 - MSE: 1.784725
# Imagem: fourShapes/triangle/270.png - Pearson: 0.6854015616275628 - MSE: 2.060325
# Imagem: fourShapes/triangle/616.png - Pearson: 0.6855684556594746 - MSE: 1.718375
# Média dos resultados de Pearson: 0.702748536129476
# Média dos resultados de MSE: 1.854475
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1014.png - Pearson: 0.6812970812464674 - MSE: 2.18025
# Imagem: fourShapes/star/511.png - Pearson: 0.6618006974085203 - MSE: 2.16035
# Imagem: fourShapes/star/2301.png - Pearson: 0.6751460885273954 - MSE: 2.047225
# Média dos resultados de Pearson: 0.672747955727461
# Média dos resultados de MSE: 2.1292750000000003
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.7768648144102839 - MSE: 2.254525
# Imagem: fourShapes/circle/805.png - Pearson: 0.7900179761646462 - MSE: 1.81365
# Imagem: fourShapes/circle/253.png - Pearson: 0.7848370816622044 - MSE: 2.376725
# Média dos resultados de Pearson: 0.7839066240790449
# Média dos resultados de MSE: 2.1483
# ========================================================
# ========================================================
# Classe: triangle
# Template: fourShapes/triangle/180.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/57.png - Pearson: 0.7226515695146488 - MSE: 1.760375
# Imagem: fourShapes/square/1338.png - Pearson: 0.6760652325745382 - MSE: 1.790425
# Imagem: fourShapes/square/1824.png - Pearson: 0.6397379914408952 - MSE: 1.933225
# Média dos resultados de Pearson: 0.6794849311766941
# Média dos resultados de MSE: 1.8280083333333332
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.5502420605606249 - MSE: 1.889525
# Imagem: fourShapes/triangle/270.png - Pearson: 0.5485505938284778 - MSE: 2.042975
# Imagem: fourShapes/triangle/616.png - Pearson: 0.8121343774920278 - MSE: 1.615975
# Média dos resultados de Pearson: 0.6369756772937102
# Média dos resultados de MSE: 1.8494916666666668
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1014.png - Pearson: 0.5489713740768263 - MSE: 2.20165
# Imagem: fourShapes/star/511.png - Pearson: 0.5687224530675999 - MSE: 2.0484
# Imagem: fourShapes/star/2301.png - Pearson: 0.6850892746752457 - MSE: 1.881375
# Média dos resultados de Pearson: 0.6009277006065573
# Média dos resultados de MSE: 2.0438083333333332
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.6281292024677521 - MSE: 2.187825
# Imagem: fourShapes/circle/805.png - Pearson: 0.6364630384618286 - MSE: 1.7316
# Imagem: fourShapes/circle/253.png - Pearson: 0.6374962834036063 - MSE: 2.334825
# Média dos resultados de Pearson: 0.6340295081110623
# Média dos resultados de MSE: 2.08475
# ========================================================
# ========================================================
# Classe: star
# Template: fourShapes/star/3.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/57.png - Pearson: 0.6150216770319686 - MSE: 1.86365
# Imagem: fourShapes/square/1338.png - Pearson: 0.5377532781336207 - MSE: 1.9064
# Imagem: fourShapes/square/1824.png - Pearson: 0.6138788309110956 - MSE: 2.00855
# Média dos resultados de Pearson: 0.588884595358895
# Média dos resultados de MSE: 1.9262000000000001
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.6036376574705882 - MSE: 2.091
# Imagem: fourShapes/triangle/270.png - Pearson: 0.5810813964196424 - MSE: 2.25775
# Imagem: fourShapes/triangle/616.png - Pearson: 0.5794520132967398 - MSE: 1.8671
# Média dos resultados de Pearson: 0.5880570223956568
# Média dos resultados de MSE: 2.07195
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1014.png - Pearson: 0.8069706702517022 - MSE: 2.000025
# Imagem: fourShapes/star/511.png - Pearson: 0.7850653131140461 - MSE: 2.179575
# Imagem: fourShapes/star/2301.png - Pearson: 0.5556046088708865 - MSE: 2.10585
# Média dos resultados de Pearson: 0.7158801974122116
# Média dos resultados de MSE: 2.09515
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.5341913900273727 - MSE: 2.28515
# Imagem: fourShapes/circle/805.png - Pearson: 0.5399760682988721 - MSE: 1.845175
# Imagem: fourShapes/circle/253.png - Pearson: 0.5402355890236552 - MSE: 2.41535
# Média dos resultados de Pearson: 0.5381343491166334
# Média dos resultados de MSE: 2.1818916666666666
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/1187.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/57.png - Pearson: 0.8290595816071737 - MSE: 1.9588
# Imagem: fourShapes/square/1338.png - Pearson: 0.8665824086872742 - MSE: 1.67015
# Imagem: fourShapes/square/1824.png - Pearson: 0.8254678160371325 - MSE: 2.14975
# Média dos resultados de Pearson: 0.8403699354438602
# Média dos resultados de MSE: 1.9262333333333335
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.667698388981193 - MSE: 1.95915
# Imagem: fourShapes/triangle/270.png - Pearson: 0.6648478234114652 - MSE: 2.21685
# Imagem: fourShapes/triangle/616.png - Pearson: 0.5924646707594718 - MSE: 1.876
# Média dos resultados de Pearson: 0.6416702943840433
# Média dos resultados de MSE: 2.017333333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/1014.png - Pearson: 0.6187513134900918 - MSE: 2.272025
# Imagem: fourShapes/star/511.png - Pearson: 0.5725545673011296 - MSE: 2.373525
# Imagem: fourShapes/star/2301.png - Pearson: 0.6060127462289626 - MSE: 2.2548
# Média dos resultados de Pearson: 0.5991062090067281
# Média dos resultados de MSE: 2.300116666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/1387.png - Pearson: 0.9469992018059893 - MSE: 2.3264
# Imagem: fourShapes/circle/805.png - Pearson: 0.9622470850733892 - MSE: 1.690175
# Imagem: fourShapes/circle/253.png - Pearson: 0.9440253251387595 - MSE: 2.315
# Média dos resultados de Pearson: 0.9510905373393793
# Média dos resultados de MSE: 2.110525
# ========================================================

# %% [markdown]
# ### Etapa B: Template Matching
#
# 1.   Refaça os experimentos da Etapa A usando a base de folhas ([download](https://www.dropbox.com/s/fmbq1bpay5joaax/Folhas.zip?dl=0)) ;
# 2.   Selecione 3 imagens aleatórias de cada uma das 3 classes ;
# 3.   Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       *  Escolha uma imagem como “template” e três imagens da mesma classe como entradas;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas ;
# 4.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %%
test_template_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# numero de arquivos:  15
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/489.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.8902820831902324 - MSE: 1.894284
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.7612724545199856 - MSE: 1.911396
# Imagem: folhas/Acer_Mono/807.jpg - Pearson: 0.8961442595076241 - MSE: 1.411432
# Média dos resultados de Pearson: 0.8492329324059473
# Média dos resultados de MSE: 1.7390373333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.7157348078738174 - MSE: 1.265596
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.6634507721904359 - MSE: 1.433956
# Imagem: folhas/Acer_Capillipes/227.jpg - Pearson: 0.7103752136829182 - MSE: 1.4393
# Média dos resultados de Pearson: 0.6965202645823905
# Média dos resultados de MSE: 1.3796173333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.5964228573127626 - MSE: 1.774208
# Imagem: folhas/Acer_Opalus/1002.jpg - Pearson: 0.6385308006133736 - MSE: 1.510528
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.6038015641101665 - MSE: 1.661348
# Média dos resultados de Pearson: 0.6129184073454342
# Média dos resultados de MSE: 1.6486946666666666
# ========================================================
# ========================================================
# Classe: Acer_Capillipes
# Template: folhas/Acer_Capillipes/569.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.7548112880594028 - MSE: 1.927188
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.5887168227860808 - MSE: 1.92774
# Imagem: folhas/Acer_Mono/807.jpg - Pearson: 0.7258835643236754 - MSE: 1.4624
# Média dos resultados de Pearson: 0.689803891723053
# Média dos resultados de MSE: 1.7724426666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.8905268431191453 - MSE: 1.115164
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.9122585199235941 - MSE: 1.184076
# Imagem: folhas/Acer_Capillipes/227.jpg - Pearson: 0.9058635708254102 - MSE: 1.235428
# Média dos resultados de Pearson: 0.9028829779560499
# Média dos resultados de MSE: 1.1782226666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.5837236655509099 - MSE: 1.661496
# Imagem: folhas/Acer_Opalus/1002.jpg - Pearson: 0.6273006512663277 - MSE: 1.431008
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.6007722895493897 - MSE: 1.546668
# Média dos resultados de Pearson: 0.6039322021222091
# Média dos resultados de MSE: 1.5463906666666667
# ========================================================
# ========================================================
# Classe: Acer_Opalus
# Template: folhas/Acer_Opalus/1125.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.5933196025097824 - MSE: 2.267296
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.46569630068027634 - MSE: 2.250512
# Imagem: folhas/Acer_Mono/807.jpg - Pearson: 0.5980852681378709 - MSE: 1.816484
# Média dos resultados de Pearson: 0.5523670571093099
# Média dos resultados de MSE: 2.1114306666666667
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.5832223015674388 - MSE: 1.510464
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.609025015989326 - MSE: 1.607888
# Imagem: folhas/Acer_Capillipes/227.jpg - Pearson: 0.6437333559691595 - MSE: 1.607432
# Média dos resultados de Pearson: 0.6119935578419747
# Média dos resultados de MSE: 1.5752613333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/317.jpg - Pearson: 0.8211987999938851 - MSE: 1.723452
# Imagem: folhas/Acer_Opalus/1002.jpg - Pearson: 0.6960605838133149 - MSE: 1.59638
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.8097962143817417 - MSE: 1.614008
# Média dos resultados de Pearson: 0.7756851993963139
# Média dos resultados de MSE: 1.6446133333333333
# ========================================================

# %% [markdown]
# ### Etapa C: Feature Matching
#
# 1.  Refaça os experimentos da Etapa A e B usando características extraídas das imagens ;
# 2.  Utilize uma característica simples como contagem de pixels pretos e brancos em zonas da imagem (3x3) ;
# 3.  Selecione as mesmas amostras como template e para calcular as diferenças.
# 4.  Utilizando o Pearson Correlation Coefficient e Erro Quadrático Médio demonstre que as imagens são mais similares entre a mesma classe e menos similares entre classes diferentes ;
#       * Escolha uma imagem como “template” e três imagens da mesma classe como entradas ;
#       * Calcule Pearson E Erro Quadrárico Médio entre elas;
# 5.  Utilizando o mesmo “template” e três imagens de cada uma das outras três classes. Repita o processo calculando o coeficiente de Pearson e Erro Quadrárico Médio entre elas ;

# %% [markdown]
# ##### Four-Shapes (Etapa A)

# %%
def test_feature_matching(folder, num_parts=3, resize=(60, 60), border_color=(255,255,255)):
    formas = u.get_files(folder)
    conjunto_formas = u.get_random_images(formas)

    for classe in conjunto_formas.keys():
        print("========================================================")
        print("Classe:", classe)
        print("Template:", conjunto_formas[classe][0])
        template = cmp.count_pixels(str(conjunto_formas[classe][0]), num_parts, resize, border_color)

        for key in conjunto_formas.keys():
            print("\n~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            print("Comparando o template com as instâncias da classe:", key)
            print("")
            
            psn, mse = [], []

            for f in conjunto_formas[key][1]:
                image = cmp.count_pixels(str(f), num_parts, resize, border_color)
                res = cmp.compare_arrays(template, image)
                psn.append(res[0])
                mse.append(res[1])
                print(f"Imagem: {f} - Pearson: {psn[-1]} - MSE: { mse[-1]}")
                # print("Pearson:", psn[-1])
                # print("MSE:", mse[-1])
                # print("")

            #print("Média para:")
            print(f"Média dos resultados de Pearson: {mean(psn)}\nMédia dos resultados de MSE: {mean(mse)}")

        print("========================================================")

# %%
test_feature_matching("fourShapes/", resize=(200, 200), border_color=(255, 255, 255))
# Out:
# numero de arquivos:  40
# ========================================================
# Classe: square
# Template: fourShapes/square/1166.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1558.png - Pearson: 0.9915893885646616 - MSE: 1148595.0
# Imagem: fourShapes/square/1338.png - Pearson: 0.9939261963400889 - MSE: 859978.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.9979585463442716 - MSE: 100950.0
# Média dos resultados de Pearson: 0.9944913770830074
# Média dos resultados de MSE: 703174.3333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.9664834066481149 - MSE: 1884225.0
# Imagem: fourShapes/triangle/270.png - Pearson: 0.9561568405234422 - MSE: 1980069.0
# Imagem: fourShapes/triangle/956.png - Pearson: 0.9305784749263556 - MSE: 2717741.0
# Média dos resultados de Pearson: 0.9510729073659709
# Média dos resultados de MSE: 2194011.6666666665
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/2088.png - Pearson: 0.9587982266016479 - MSE: 4585217.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.965730169351285 - MSE: 3168199.0
# Imagem: fourShapes/star/1179.png - Pearson: 0.9685931231852618 - MSE: 2721044.0
# Média dos resultados de Pearson: 0.9643738397127316
# Média dos resultados de MSE: 3491486.6666666665
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2351.png - Pearson: 0.9971838040002304 - MSE: 141045.0
# Imagem: fourShapes/circle/1187.png - Pearson: 0.990302748826604 - MSE: 742094.0
# Imagem: fourShapes/circle/2661.png - Pearson: 0.9991174356007109 - MSE: 26459.0
# Média dos resultados de Pearson: 0.9955346628091818
# Média dos resultados de MSE: 303199.3333333333
# ========================================================
# ========================================================
# Classe: triangle
# Template: fourShapes/triangle/11.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1558.png - Pearson: 0.9481792870649833 - MSE: 6305620.0
# Imagem: fourShapes/square/1338.png - Pearson: 0.9579304686298526 - MSE: 5593693.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.9547300765684122 - MSE: 3017567.0
# Média dos resultados de Pearson: 0.9536132774210827
# Média dos resultados de MSE: 4972293.333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.9832196578741785 - MSE: 624792.0
# Imagem: fourShapes/triangle/270.png - Pearson: 0.9698579086725965 - MSE: 1018284.0
# Imagem: fourShapes/triangle/956.png - Pearson: 0.9418078056361752 - MSE: 1521762.0
# Média dos resultados de Pearson: 0.9649617907276501
# Média dos resultados de MSE: 1054946.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/2088.png - Pearson: 0.982779563040713 - MSE: 457246.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.9789265442990027 - MSE: 404798.0
# Imagem: fourShapes/star/1179.png - Pearson: 0.9930946404206706 - MSE: 156165.0
# Média dos resultados de Pearson: 0.9849335825867954
# Média dos resultados de MSE: 339403.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2351.png - Pearson: 0.9617323457051996 - MSE: 2698046.0
# Imagem: fourShapes/circle/1187.png - Pearson: 0.9019729817370433 - MSE: 6904893.0
# Imagem: fourShapes/circle/2661.png - Pearson: 0.9480313497185135 - MSE: 3586594.0
# Média dos resultados de Pearson: 0.9372455590535855
# Média dos resultados de MSE: 4396511.0
# ========================================================
# ========================================================
# Classe: star
# Template: fourShapes/star/1014.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1558.png - Pearson: 0.969154606771126 - MSE: 5494209.0
# Imagem: fourShapes/square/1338.png - Pearson: 0.9733489491858148 - MSE: 4917082.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.9755030982631786 - MSE: 2305740.0
# Média dos resultados de Pearson: 0.9726688847400398
# Média dos resultados de MSE: 4239010.333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.9952909264884043 - MSE: 297601.0
# Imagem: fourShapes/triangle/270.png - Pearson: 0.9845961947854895 - MSE: 624407.0
# Imagem: fourShapes/triangle/956.png - Pearson: 0.9581651841520953 - MSE: 1109041.0
# Média dos resultados de Pearson: 0.9793507684753298
# Média dos resultados de MSE: 677016.3333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/2088.png - Pearson: 0.9914448935769009 - MSE: 371813.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.991153956609802 - MSE: 177933.0
# Imagem: fourShapes/star/1179.png - Pearson: 0.99745805779012 - MSE: 55310.0
# Média dos resultados de Pearson: 0.9933523026589409
# Média dos resultados de MSE: 201685.33333333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2351.png - Pearson: 0.9807394419171596 - MSE: 2039691.0
# Imagem: fourShapes/circle/1187.png - Pearson: 0.9339370279921855 - MSE: 5815504.0
# Imagem: fourShapes/circle/2661.png - Pearson: 0.9701530533253527 - MSE: 2820943.0
# Média dos resultados de Pearson: 0.9616098410782326
# Média dos resultados de MSE: 3558712.6666666665
# ========================================================
# ========================================================
# Classe: circle
# Template: fourShapes/circle/5.png
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: square
#
# Imagem: fourShapes/square/1558.png - Pearson: 0.9949958989118514 - MSE: 1418493.0
# Imagem: fourShapes/square/1338.png - Pearson: 0.9963026205369331 - MSE: 1112418.0
# Imagem: fourShapes/square/1824.png - Pearson: 0.9997615477300077 - MSE: 7916.0
# Média dos resultados de Pearson: 0.9970200223929307
# Média dos resultados de MSE: 846275.6666666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: triangle
#
# Imagem: fourShapes/triangle/833.png - Pearson: 0.9740191441753955 - MSE: 1432007.0
# Imagem: fourShapes/triangle/270.png - Pearson: 0.9600372453713404 - MSE: 1668309.0
# Imagem: fourShapes/triangle/956.png - Pearson: 0.9291713332076497 - MSE: 2520773.0
# Média dos resultados de Pearson: 0.9544092409181285
# Média dos resultados de MSE: 1873696.3333333333
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: star
#
# Imagem: fourShapes/star/2088.png - Pearson: 0.9678782870348849 - MSE: 3855655.0
# Imagem: fourShapes/star/2301.png - Pearson: 0.9753956764216417 - MSE: 2514247.0
# Imagem: fourShapes/star/1179.png - Pearson: 0.979120746344982 - MSE: 2087998.0
# Média dos resultados de Pearson: 0.9741315699338362
# Média dos resultados de MSE: 2819300.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: circle
#
# Imagem: fourShapes/circle/2351.png - Pearson: 0.9990165914187716 - MSE: 32989.0
# Imagem: fourShapes/circle/1187.png - Pearson: 0.9860950284874969 - MSE: 1143564.0
# Imagem: fourShapes/circle/2661.png - Pearson: 0.9991972051200715 - MSE: 53869.0
# Média dos resultados de Pearson: 0.9947696083421134
# Média dos resultados de MSE: 410140.6666666667
# ========================================================

# %% [markdown]
# ##### Folhas (Etapa B)

# %%
test_feature_matching("folhas/", resize=(500, 500), border_color=(0, 0, 0))
# Out:
# numero de arquivos:  15
# ========================================================
# Classe: Acer_Mono
# Template: folhas/Acer_Mono/216.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.9805290356331811 - MSE: 45497317.0
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.9602564509026836 - MSE: 52217895.0
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.9948801307631693 - MSE: 11130528.0
# Média dos resultados de Pearson: 0.9785552057663447
# Média dos resultados de MSE: 36281913.333333336
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.9120080557624409 - MSE: 186519383.0
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.9205950244745921 - MSE: 143329204.0
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.9495270885359268 - MSE: 85523986.0
# Média dos resultados de Pearson: 0.9273767229243199
# Média dos resultados de MSE: 138457524.33333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.9010636600271558 - MSE: 488773909.0
# Imagem: folhas/Acer_Opalus/906.jpg - Pearson: 0.866339363747955 - MSE: 647568191.0
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.8816781621779618 - MSE: 612828911.0
# Média dos resultados de Pearson: 0.8830270619843575
# Média dos resultados de MSE: 583057003.6666666
# ========================================================
# ========================================================
# Classe: Acer_Capillipes
# Template: folhas/Acer_Capillipes/227.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.9646603640526267 - MSE: 67378122.0
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.8024562164876619 - MSE: 316880802.0
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.9303988082682987 - MSE: 137228235.0
# Média dos resultados de Pearson: 0.899171796269529
# Média dos resultados de MSE: 173829053.0
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.9964915624996152 - MSE: 5218356.0
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.9932100087947326 - MSE: 21342573.0
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.9871237463927169 - MSE: 52605907.0
# Média dos resultados de Pearson: 0.9922751058956882
# Média dos resultados de MSE: 26388945.333333332
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.8347521248733021 - MSE: 334158458.0
# Imagem: folhas/Acer_Opalus/906.jpg - Pearson: 0.8049032220015596 - MSE: 440707422.0
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.8474503308342596 - MSE: 375669280.0
# Média dos resultados de Pearson: 0.8290352259030405
# Média dos resultados de MSE: 383511720.0
# ========================================================
# ========================================================
# Classe: Acer_Opalus
# Template: folhas/Acer_Opalus/317.jpg
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Mono
#
# Imagem: folhas/Acer_Mono/499.jpg - Pearson: 0.8796511974293388 - MSE: 491944186.0
# Imagem: folhas/Acer_Mono/288.jpg - Pearson: 0.783333725673012 - MSE: 722539574.0
# Imagem: folhas/Acer_Mono/489.jpg - Pearson: 0.8758531834966481 - MSE: 576021529.0
# Média dos resultados de Pearson: 0.8462793688663329
# Média dos resultados de MSE: 596835096.3333334
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Capillipes
#
# Imagem: folhas/Acer_Capillipes/498.jpg - Pearson: 0.7518703739850503 - MSE: 553123568.0
# Imagem: folhas/Acer_Capillipes/201.jpg - Pearson: 0.7389039108220767 - MSE: 673587815.0
# Imagem: folhas/Acer_Capillipes/610.jpg - Pearson: 0.7559180294808797 - MSE: 741787033.0
# Média dos resultados de Pearson: 0.7488974380960023
# Média dos resultados de MSE: 656166138.6666666
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Comparando o template com as instâncias da classe: Acer_Opalus
#
# Imagem: folhas/Acer_Opalus/1.jpg - Pearson: 0.9842871545074737 - MSE: 33936524.0
# Imagem: folhas/Acer_Opalus/906.jpg - Pearson: 0.9941969637184483 - MSE: 11037664.0
# Imagem: folhas/Acer_Opalus/1125.jpg - Pearson: 0.9909316760150692 - MSE: 15410960.0
# Média dos resultados de Pearson: 0.989805264746997
# Média dos resultados de MSE: 20128382.666666668
# ========================================================
